# %% [markdown]
# # Objects and Data Structures Assessment Test

# %% [markdown]
# ## Test your knowledge.
#
# ** Answer the following questions **

# %% [markdown]
# Write a brief description of all the following Object Types and Data Structures we've learned about:

# %% [markdown]
# Numbers: In this data type we read inputs and print outputs in the form of whole numbers. We declare them using int for integers
#          and float for decimal numbers and exponents. Both positive and negative numbers are acceptible.
#
# Strings: This data type is collection of characters as one element. Ex "My name is Karthik and I'm 19 years old"
#
# Lists: This data type is an ordered collection of characters. This data type is mutable and new items can be appended. The collection of items is enclosed in a [].
#
# Tuples: This data type is similar to lists but its one element can hold 2 values. They are aalso immutable, so adding or deleting elements is not possible
#
# Dictionaries: In this data type each element is mapped to a key. It is changeable and there is no duplication of elements.

# %% [markdown]
# ## Numbers
#
# Write an equation that uses multiplication, division, an exponent, addition, and subtraction that is equal to 100.25.
#
# Hint: This is just to test your memory of the basic arithmetic commands, work backwards from 100.25

# %%
(1 / 2**2) + ((200 - 150) * 2)
# Out:
# 100.25

# %% [markdown]
# Answer these 3 questions without typing code. Then type code to check your answer.
#
#     What is the value of the expression 4 * (6 + 5) = 44
#
#     What is the value of the expression 4 * 6 + 5   = 29
#
#     What is the value of the expression 4 + 6 * 5   = 34

# %%
4 * (6 + 5)
# Out:
# 44

# %%
4 * 6 + 5
# Out:
# 29

# %%
4 + 6 * 5
# Out:
# 34

# %% [markdown]
# What is the *type* of the result of the expression 3 + 1.5 + 4?<br><br>

# %%
check_type = 3 + 1.5 + 4

# %%
type(check_type)
# Out:
# float

# %% [markdown]
# What would you use to find a number’s square root, as well as its square?

# %%
# Square root: 

123456 ** 0.5
# Out:
# 351.363060095964

# %%
# Square:

789 ** 2
# Out:
# 622521

# %% [markdown]
# ## Strings

# %% [markdown]
# Given the string 'hello' give an index command that returns 'e'. Enter your code in the cell below:

# %%
s = 'hello'
# Print out 'e' using indexing

s[1]
# Out:
# 'e'

# %% [markdown]
# Reverse the string 'hello' using slicing:

# %%
s ='hello'
# Reverse the string using slicing

s[::-1]
# Out:
# 'olleh'

# %% [markdown]
# Given the string hello, give two methods of producing the letter 'o' using indexing.

# %%
s ='hello'
# Print out the 'o'

# Method 1:

s[4]
# Out:
# 'o'

# %%
# Method 2:

s[-1]
# Out:
# 'o'

# %% [markdown]
# ## Lists

# %% [markdown]
# Build this list [0,0,0] two separate ways.

# %%
# Method 1:

list = [0,0,0]
list
# Out:
# [0, 0, 0]

# %%
# Method 2:

[0] * 3
# Out:
# [0, 0, 0]

# %% [markdown]
# Reassign 'hello' in this nested list to say 'goodbye' instead:

# %%
list3 = [1,2,[3,4,'hello']]

list3[2][2] = 'goodbye'
list3
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %% [markdown]
# Sort the list below:

# %%
list4 = [5,3,4,6,1]

list4.sort()
list4
# Out:
# [1, 3, 4, 5, 6]

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# Using keys and indexing, grab the 'hello' from the following dictionaries:

# %%
d = {'simple_key':'hello'}
# Grab 'hello'

d['simple_key']
# Out:
# 'hello'

# %%
d = {'k1':{'k2':'hello'}}
# Grab 'hello'

d['k1']['k2']
# Out:
# 'hello'

# %%
# Getting a little tricker
d = {'k1':[{'nest_key':['this is deep',['hello']]}]}

#Grab hello

d['k1'][0]['nest_key'][1][0]
# Out:
# 'hello'

# %%
# This will be hard and annoying!
d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}

# sorry I am unable to solve it, please teach me.

# %% [markdown]
# Can you sort a dictionary? Why or why not?<br><br>
#
# No. In dictionaries the elements are mapped to a key and thus they cannot be sorted. For example, Dict_example = {'Company':'Apple', 'Fruit':'Banana} cannot be sorted as Apple and Banana are mapped to Company and Fruit respectively.

# %% [markdown]
# ## Tuples

# %% [markdown]
# What is the major difference between tuples and lists?<br><br>
#
# Lists are mutable that is changeable or can be altered whereas tuples cannot be changes and are immutable.

# %% [markdown]
# How do you create a tuple?<br><br>
#
# Tuples are created like this tuple_example = (1, 2, 'three').

# %% [markdown]
# ## Sets

# %% [markdown]
# What is unique about a set?<br><br>
#
# In sets, there is no repetition of elements. This makes every element distinct and unique.

# %% [markdown]
# Use a set to find the unique values of the list below:

# %%
list5 = [1,2,2,33,4,4,11,22,3,3,2]

set(list5)
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %% [markdown]
# ## Booleans

# %% [markdown]
# For the following quiz questions, we will get a preview of comparison operators. In the table below, a=3 and b=4.
#
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td> (a != b) is true.</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %% [markdown]
# What will be the resulting Boolean of the following pieces of code (answer fist then check by typing it in!)

# %%
# Answer before running cell = False
2 > 3
# Out:
# False

# %%
# Answer before running cell = False
3 <= 2
# Out:
# False

# %%
# Answer before running cell = False
3 == 2.0
# Out:
# False

# %%
# Answer before running cell = True
3.0 == 3
# Out:
# True

# %%
# Answer before running cell = False
4**0.5 != 2
# Out:
# False

# %% [markdown]
# Final Question: What is the boolean output of the cell block below?

# %%
# two nested lists
l_one = [1,2,[3,4]]
l_two = [1,2,{'k1':4}]

# True or False?
l_one[2][0] >= l_two[2]['k1']

# False, as 3 >! 4.
# Out:
# False

# %% [markdown]
# ## Great Job on your first assessment!
